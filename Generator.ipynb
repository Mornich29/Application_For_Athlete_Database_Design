# %%
import names
import random 
import csv
import datetime
import pandas as pd

# %%
gender = ["M","F"]
sport_type = ["Football" , "Basketball" , "Tennis", "PingPong" , "Badminton" , "Boxing","Athletic" , "VolleyBall"]
Nation = ["Thai","American","Japanese","Korean" ,"Brazilian","German","Italian","British","French","Russian","Mexican"]
Name = ["Mahidol Sport","ICT Sport","KingKong Sport", "Arm Sport","GD Sport","Underdogs Sport","Man Uay FC","Big Boom FC","Easy Team","Uefa191","CC Sport",
        "Good Team","Pheonix FC","Green Sport","FairPlay Sport","The Best Team","Beyonder","One Above All","Superman","Batman Sport","Rich Kid","GG Sport",
        "XX Sport","Rama Sport","MM Sport","Green Velvet"]
athlete = 1000
team = 25
shuffle = []
for i in range(0,880):
    shuffle.append("Thai")

for i in range(880,890):
    shuffle.append("American")

for i in range(890,900):
    shuffle.append("Japanese")

for i in range(900,940):
    shuffle.append("Korean")

for i in range(940,970):
    shuffle.append("German")

for i in range(970,999):
    shuffle.append("Canadian")

shuffle.append("Italian")

random.shuffle(shuffle)

# %%
for x in range(0,athlete):
    print("("
     + "'" + str(x).zfill(5) + "'" +"," + "'" + names.get_first_name()+"'"  +"," + "'" + names.get_last_name()+ "'" + "," + str(random.randint(150,200)) + "," + 
     str(round(random.uniform(40,100),2))+"," + str(random.randint(15,45)) + "," + "'"+ random.choice(gender) +"'" + "," + "'"+random.choice(sport_type)+"'"+ 
     "," + "'" + shuffle[x] + "'" + ","+ "'"+random.choice(Name) +"'"+
    ")" + ",")
# Out:
# ('00000','Blanche','Mason',187,64.36,35,'F','Badminton','Thai','MM Sport'),
# ('00001','Alene','Perkins',151,83.36,23,'F','Football','Thai','Superman'),
# ('00002','Brady','Hotaling',151,84.3,24,'F','Basketball','Thai','Arm Sport'),
# ('00003','Joan','Gomez',151,47.05,38,'F','Basketball','Thai','MM Sport'),
# ('00004','Mary','Pitts',161,84.38,29,'F','PingPong','American','Man Uay FC'),
# ('00005','Julian','Murphy',182,98.94,19,'M','VolleyBall','Thai','Pheonix FC'),
# ('00006','Edna','Taylor',166,44.36,29,'F','Basketball','Korean','Beyonder'),
# ('00007','Delphine','Cogliano',198,47.25,32,'F','VolleyBall','Thai','GG Sport'),
# ('00008','Billy','Squier',150,52.03,37,'M','Boxing','Thai','Pheonix FC'),
# ('00009','Thomas','Clayton',162,72.76,32,'F','Athletic','Thai','KingKong Sport'),
# ('00010','Edward','Breeden',165,95.03,44,'F','PingPong','Thai','Man Uay FC'),
# ('00011','Michael','Cannon',199,45.29,43,'M','VolleyBall','Thai','Beyonder'),
# ...

# %%
atlist = []
for x in range(0,athlete):
    atlist.append([str(x).zfill(5),names.get_first_name(),names.get_last_name(),str(random.randint(150,200)),str(round(random.uniform(40,100),2)),str(random.randint(15,45)),random.choice(gender),
                    random.choice(sport_type), shuffle[x], random.choice(Name)])

# %%
atdf = pd.DataFrame(atlist, columns = ['Athlete_ID', 'FirstName','LastName','Ath_Height','Ath_Weight','Age','Gender','Sport_Type','Nationality','Team_Name'])

# %%
atdf
# Out:
#     Athlete_ID FirstName   LastName Ath_Height Ath_Weight Age Gender  \
# 0        00000  Lucrecia  Delbridge        181      56.05  45      M
# 1        00001      Seth     Harris        172      84.94  25      M
# 2        00002    Janice  Rodriguez        180      77.61  32      M
# 3        00003  Margaret     Tullar        179      71.47  27      M
# 4        00004     Felix      Smith        198      51.59  19      M
# ..         ...       ...        ...        ...        ...  ..    ...
# 995      00995   Cameron  Ratermann        189      55.33  19      F
# 996      00996      Anne    Staples        173      87.99  23      M
# 997      00997   Michael    Collins        182       72.3  15      F
# 998      00998     Hazel      Truax        195       60.0  20      F
# 999      00999     Lloyd      White        161      65.38  34      F
#
#      Sport_Type Nationality        Team_Name
# 0        Boxing        Thai       Pheonix FC
# 1    VolleyBall        Thai  Underdogs Sport
# ...

# %%
start_date = datetime.date(1970, 2, 14)
end_date = datetime.date(2020, 1, 1)

# %%
for x in range(0,team +1):
    
    time_between_dates = end_date - start_date
    days_between_dates = time_between_dates.days
    random_number_of_days = random.randrange(days_between_dates)
    random_date = start_date + datetime.timedelta(days=random_number_of_days)
    print("("
     + "'"+ Name[x] + "'" + "," + "'" + random.choice(sport_type) + "'" + ","  + "'" + str(random_date) + "'"+ 
    ")" + ",")
# Out:
# ('Mahidol Sport','Basketball','2001-12-19'),
# ('ICT Sport','Basketball','2017-04-05'),
# ('KingKong Sport','Football','1981-03-10'),
# ('Arm Sport','Basketball','2005-11-06'),
# ('GD Sport','Boxing','2000-08-24'),
# ('Underdogs Sport','Boxing','2002-10-22'),
# ('Man Uay FC','VolleyBall','1984-12-18'),
# ('Big Boom FC','PingPong','1970-05-14'),
# ('Easy Team','PingPong','1971-04-08'),
# ('Uefa191','Boxing','1999-08-08'),
# ('CC Sport','Basketball','1997-06-23'),
# ('Good Team','Basketball','1995-06-25'),
# ('Pheonix FC','Football','1984-05-12'),
# ('Green Sport','Basketball','2002-12-01'),
# ('FairPlay Sport','VolleyBall','1990-11-18'),
# ('The Best Team','Tennis','2003-03-21'),
# ('Beyonder','Athletic','1994-05-12'),
# ('One Above All','PingPong','2014-06-14'),
# ('Superman','Tennis','1987-12-04'),
# ('Batman Sport','Football','1985-03-07'),
# ('Rich Kid','Athletic','2003-03-09'),
# ('GG Sport','Tennis','1977-12-23'),
# ('XX Sport','Tennis','1973-01-31'),
# ...

# %%
teamlist = []
for x in range(0,team +1):
    time_between_dates = end_date - start_date
    days_between_dates = time_between_dates.days
    random_number_of_days = random.randrange(days_between_dates)
    random_date = start_date + datetime.timedelta(days=random_number_of_days)
    teamlist.append([Name[x],random.choice(sport_type),str(random_date)])

# %%
teamdf = pd.DataFrame(teamlist, columns = ['Team_Name','Type_Of_Sport','Founded_Date'])

# %%
teamdf
# Out:
#           Team_Name Type_Of_Sport Founded_Date
# 0     Mahidol Sport      PingPong   1984-11-25
# 1         ICT Sport     Badminton   1993-01-27
# 2    KingKong Sport     Badminton   2018-01-17
# 3         Arm Sport        Boxing   2013-09-07
# 4          GD Sport      Athletic   1983-02-26
# 5   Underdogs Sport      PingPong   1975-04-15
# 6        Man Uay FC        Boxing   1985-01-18
# 7       Big Boom FC      Football   2015-09-15
# 8         Easy Team        Tennis   1977-02-19
# 9           Uefa191      Football   2016-11-20
# 10         CC Sport     Badminton   1985-07-29
# 11        Good Team        Tennis   1995-10-10
# 12       Pheonix FC    Basketball   1999-09-02
# 13      Green Sport        Tennis   1994-03-22
# 14   FairPlay Sport        Boxing   1998-04-24
# 15    The Best Team    Basketball   1984-10-03
# 16         Beyonder      PingPong   1985-08-23
# 17    One Above All    Basketball   1991-02-01
# 18         Superman     Badminton   1991-12-28
# ...

# %%
medical = 70
Branch = ["Ophthalmologists","Neurologists","Nephrologists","Internists","Hematologists","Endocrinologists","Dermatologists","Critical Care Medicine Specialists","Cardiologists",
            "Psycologist"]
staff = []

# for i in range(0,40):
#     first = "0"+ str(random.randint(80,93))
#     second = str(random.randint(0,999)).zfill(3)
#     third = str(random.randint(0,9999)).zfill(4)
#     print(first + "-" + second+ "-" + third)
# for x in range(0,70):
#     first = "0"+ str(random.randint(80,93))
#     second = str(random.randint(0,999)).zfill(3)
#     third = str(random.randint(0,9999)).zfill(4)
#     staff.append("("
#      + "'" + str(x).zfill(5) +  "'" +"," + "'" + names.get_first_name()+"'"  +"," + "'" + names.get_last_name()+ "'" + "," + "'" + random.choice(Branch) + "'"+  "," + 
#      "'" +"Assistant"+ "'" +"," + "'" + first + "-" + second+ "-" + third + "'"+
#     ")" + ",")

medicallist = []

for x in range(0,70):
    first = "0"+ str(random.randint(80,93))
    second = str(random.randint(0,999)).zfill(3)
    third = str(random.randint(0,9999)).zfill(4)
    medicallist.append([str(x).zfill(5),names.get_first_name(),names.get_last_name(),random.choice(Branch),"Assistant",first +'-' + second + "-" + third])

dfmedical = pd.DataFrame(medicallist, columns = ['Medical_Staff_ID','FirstName','LastName','Branch','Position','Phone'])

# %%
dfmedical
# Out:
#    Medical_Staff_ID  FirstName   LastName            Branch   Position  \
# 0             00000  Carmelita   Federico        Internists  Assistant
# 1             00001      Brian  Wilkowitz     Hematologists  Assistant
# 2             00002   Clarence     Cusack       Psycologist  Assistant
# 3             00003      Kevin     Garica     Nephrologists  Assistant
# 4             00004    Stephen     Harris        Internists  Assistant
# ..              ...        ...        ...               ...        ...
# 65            00065      Scott     Hipple        Internists  Assistant
# 66            00066  Shantelle  Gunderman        Internists  Assistant
# 67            00067    Tiffani    Pavlick  Endocrinologists  Assistant
# 68            00068        Don      Trout  Endocrinologists  Assistant
# 69            00069       Mark      Smith  Ophthalmologists  Assistant
#
#            Phone
# 0   086-760-4853
# 1   085-387-8997
# 2   087-883-1751
# 3   082-850-7652
# 4   082-316-0420
# ...

# %%
title = 'Ophthalmologists'
for i in range (0, len(staff)):
    if(title in staff[i]):
        print(staff[i])
# Out:
# ('00004','Jerry','Moyes','Ophthalmologists','Assistant','087-511-1091'),
# ('00005','Patricia','Hubbard','Ophthalmologists','Assistant','091-623-6248'),
# ('00032','Marvin','Kern','Ophthalmologists','Assistant','082-427-4244'),
# ('00034','Henry','Caruso','Ophthalmologists','Assistant','088-612-3746'),
# ('00038','Pamela','Kendrick','Ophthalmologists','Assistant','088-519-2682'),
# ('00039','Christopher','Wolf','Ophthalmologists','Assistant','086-762-3818'),
# ('00041','Josephine','Cirrincione','Ophthalmologists','Assistant','091-880-8683'),
# ('00044','Arlene','Daniels','Ophthalmologists','Assistant','087-187-9473'),
# ('00049','John','Parrish','Ophthalmologists','Assistant','086-530-5960'),
# ('00051','Stephen','Esparza','Ophthalmologists','Assistant','089-945-6390'),
# ('00057','Georgia','Brunet','Ophthalmologists','Assistant','083-561-9115'),
# ('00065','Mary','Diberardino','Ophthalmologists','Assistant','087-322-8549'),

# %%
for i in range(0,70):
    print(staff[i])
# Out:
# ('00000','Velma','Williams','Endocrinologists','Assistant','082-760-3241'),
# ('00001','Richard','Avila','Cardiologists','Assistant','088-613-4492'),
# ('00002','Douglas','Wilson','Critical Care Medicine Specialists','Assistant','082-134-8047'),
# ('00003','Kenneth','Pittman','Cardiologists','Assistant','081-491-3497'),
# ('00004','Jerry','Moyes','Ophthalmologists','Assistant','087-511-1091'),
# ('00005','Patricia','Hubbard','Ophthalmologists','Assistant','091-623-6248'),
# ('00006','Hattie','Seales','Neurologists','Assistant','082-168-7487'),
# ('00007','Melissa','Duvall','Critical Care Medicine Specialists','Assistant','083-107-9862'),
# ('00008','Alvin','Sedillo','Nephrologists','Assistant','087-166-3376'),
# ('00009','Natalie','Shannon','Endocrinologists','Assistant','085-820-8588'),
# ('00010','Howard','Cole','Neurologists','Assistant','091-289-3347'),
# ('00011','Mike','Reeder','Hematologists','Assistant','083-773-5934'),
# ...

# %%
psycolist = []
num = 100
start_date = datetime.date(2021, 2, 14)
end_date = datetime.date(2021, 12, 1)

psyco_start = datetime.date(2021, 12, 2)
psyco_end = datetime.date(2022, 12, 14)


for x in range(0,num):
    time_between_dates = end_date - start_date
    days_between_dates = time_between_dates.days
    random_number_of_days = random.randrange(days_between_dates)
    random_date = start_date + datetime.timedelta(days=random_number_of_days)

    tb = psyco_end - psyco_start
    nextstep = tb.days
    nextstepp = random.randrange(nextstep)
    randomstep = psyco_start + datetime.timedelta(days=nextstepp)
    psycolist.append([str(x).zfill(5),str(random.randint(0,999)).zfill(5),str(random.randint(0,69)).zfill(5),str(random_date),str(random.randint(0,10)),str(round(random.uniform(0,100),2)),
                        str(round(random.uniform(0,10),2)), str(randomstep)])
    # print("("
    #  + "'" + str(x).zfill(5) +  "'" +"," + "'" + str(random.randint(0,999)).zfill(5) +"'" + "," + "'" + str(random.randint(0,69)).zfill(5)   + "'"+  "," + 
    #  "'" +str(random_date)+ "'" +"," + str(random.randint(0,10))+ ","+ str(round(random.uniform(0,100),2)) + "," +str(round(random.uniform(0,10),2))  +","+ "'" +str(randomstep)
    #  + "'"+
    # ")" + ",")

# %%
psycodf = pd.DataFrame(psycolist, columns=['Psyco_ID','Athlete_ID','Medical_Staff_ID','Recovery_Started_Date','Sleep_Quality','I_PRRS_Score','VAS_F','Recovery_Ended_Date'])

# %%
psycodf
# Out:
#    Psyco_ID Athlete_ID Medical_Staff_ID Recovery_Started_Date Sleep_Quality  \
# 0     00000      00593            00051            2021-08-28             2
# 1     00001      00929            00069            2021-06-04             5
# 2     00002      00260            00050            2021-04-27             7
# 3     00003      00632            00063            2021-09-21            10
# 4     00004      00563            00009            2021-10-21             2
# ..      ...        ...              ...                   ...           ...
# 95    00095      00823            00015            2021-10-04             2
# 96    00096      00259            00063            2021-08-08             0
# 97    00097      00447            00008            2021-02-17             3
# 98    00098      00844            00046            2021-03-22             0
# 99    00099      00591            00054            2021-07-16             0
#
#    I_PRRS_Score VAS_F Recovery_Ended_Date
# ...

# %%
injurylist = []
num = 100
start_date = datetime.date(2021, 2, 14)
end_date = datetime.date(2021, 12, 1)

psyco_start = datetime.date(2021, 12, 2)
psyco_end = datetime.date(2022, 12, 14)

event = ["During the match", "After the match", "During Training", "After Training","While Sleeping", "Daily Life Accident"]
Body_part = ["Left Arm","Right Arm","Chest","Left Hand","Right Hand","Right Leg","Left Leg","Right Foot","Left Foot","Skull","Back","Shoulder","Immune System" , "Brain","Right Eye",
            "Left Eye","Heart","Stomach","Nose","Teeth","Mouth","Face"]
cause = ["Tackle","Effect after the training or match","Body System Failure","Daily Accident"]

for x in range(0,num):
    time_between_dates = end_date - start_date
    days_between_dates = time_between_dates.days
    random_number_of_days = random.randrange(days_between_dates)
    random_date = start_date + datetime.timedelta(days=random_number_of_days)

    tb = psyco_end - psyco_start
    nextstep = tb.days
    nextstepp = random.randrange(nextstep)
    randomstep = psyco_start + datetime.timedelta(days=nextstepp)
    injurylist.append([str(x).zfill(5),str(random.randint(0,999)).zfill(5),str(random.randint(0,69)).zfill(5),str(random_date),str(random.choice(event)),str(random.choice(Body_part)),str(random.randint(1,6)),
                        str(random.choice(cause)),str(randomstep)])
    # print("("
    #  + "'" + str(x).zfill(5) +  "'" +"," + "'" + str(random.randint(0,999)).zfill(5) +"'" + "," + "'" + str(random.randint(0,69)).zfill(5)   + "'"+  "," + 
    #  "'" +str(random_date)+ "'" +"," + "'" + str(random.choice(event)) + "'" + "," +"'" + str(random.choice(Body_part))+ "'"+ "," + str(random.randint(1,6)) +","
    #  "'" + str(random.choice(cause))+ "'" + ","+ "'" +str(randomstep)+ "'"+
    # ")" + ",")

# %%
injurydf = pd.DataFrame(injurylist, columns=['Injury_ID','Athlete_ID','Medical_Staff_ID','Recovery_Started_Date','Event_Injury','Body_Part','Abbreviated_Injury_Scale','Cause_Of_Injury','Recovery_Ended_Date'])

# %%
injurydf
# Out:
#    Injury_ID Athlete_ID Medical_Staff_ID Recovery_Started_Date  \
# 0      00000      00956            00056            2021-06-19
# 1      00001      00066            00063            2021-04-16
# 2      00002      00005            00064            2021-10-24
# 3      00003      00790            00028            2021-06-23
# 4      00004      00327            00018            2021-04-09
# ..       ...        ...              ...                   ...
# 95     00095      00535            00022            2021-05-13
# 96     00096      00681            00044            2021-10-17
# 97     00097      00456            00054            2021-09-10
# 98     00098      00859            00016            2021-02-15
# 99     00099      00646            00015            2021-03-18
#
#            Event_Injury      Body_Part Abbreviated_Injury_Scale  \
# 0        While Sleeping           Nose                        5
# 1   Daily Life Accident          Mouth                        6
# ...

# %%
illnesslist = []
num = 100
start_date = datetime.date(2021, 2, 14)
end_date = datetime.date(2021, 12, 1)

psyco_start = datetime.date(2021, 12, 2)
psyco_end = datetime.date(2022, 12, 14)

Diagonis = ["Malaria","Dengue","Japanese Encephalitis","Leptospirosis","Soil-transmitted worm diseases","Sexually Transmitted Diseases","Tuberculosis","Seasonal Flu","Food Poisoning",
            "Water Borne Diseases","Traffic Accidents","Rabies","Snakebites"]
Symptom = ["Fever","Chills","Congestion","Fatigue","headache","Muscle aches","Bloody diarrhea","Vomiting","Dehydration","Shock"]

for x in range(0,num):
    time_between_dates = end_date - start_date
    days_between_dates = time_between_dates.days
    random_number_of_days = random.randrange(days_between_dates)
    random_date = start_date + datetime.timedelta(days=random_number_of_days)

    tb = psyco_end - psyco_start
    nextstep = tb.days
    nextstepp = random.randrange(nextstep)
    randomstep = psyco_start + datetime.timedelta(days=nextstepp)
    illnesslist.append([str(x).zfill(5),str(random.randint(0,999)).zfill(5),str(random.randint(0,69)).zfill(5),str(random_date),str(random.choice(Diagonis)),str(random.choice(Symptom)),str(randomstep)])
    # print("("
    #  + "'" + str(x).zfill(5) +  "'" +"," + "'" + str(random.randint(0,999)).zfill(5) +"'" + "," + "'" + str(random.randint(0,69)).zfill(5)   + "'"+  "," + 
    #  "'" +str(random_date)+ "'" +"," + "'" + str(random.choice(Diagonis)) + "'" + "," +"'" + str(random.choice(Symptom))+ "'" + ","+ "'" +str(randomstep)+ "'"+
    # ")" + ",")

# %%
illnessdf = pd.DataFrame(illnesslist, columns=['Illness_Case_ID','Athlete_ID','Medical_Staff_ID','Recovery_Started_Date','Diagnoses','Symptom','Recovery_Ended_Date'])

# %%
illnessdf
# Out:
#    Illness_Case_ID Athlete_ID Medical_Staff_ID Recovery_Started_Date  \
# 0            00000      00278            00024            2021-09-03
# 1            00001      00883            00058            2021-10-18
# 2            00002      00532            00035            2021-10-03
# 3            00003      00023            00045            2021-08-02
# 4            00004      00982            00065            2021-11-11
# ..             ...        ...              ...                   ...
# 95           00095      00699            00027            2021-06-30
# 96           00096      00385            00010            2021-04-28
# 97           00097      00400            00005            2021-06-01
# 98           00098      00707            00028            2021-07-19
# 99           00099      00908            00010            2021-06-06
#
#                          Diagnoses          Symptom Recovery_Ended_Date
# ...

# %%
illnessdf.to_csv('Illness.csv', index=False)
injurydf.to_csv('Injury.csv',index = False)
psycodf.to_csv('Psycological_Case.csv',index = False)
dfmedical.to_csv('Medical_Staff.csv',index =False)
teamdf.to_csv('Sport_Team.csv',index =False)
atdf.to_csv('Athlete.csv',index =False)
